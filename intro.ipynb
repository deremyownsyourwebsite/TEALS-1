# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Input and Output

# %%
print("Hello world!")

# %%
print("AAAAAA","BBBBBB","CCCCCC")

# %%
print("AAAAAA" "BBBBBB" "CCCCCC")

# %%
print(ABCD)

# %%
input()

# %%
input("Please enter your name")

# %% [markdown]
# ## Variables

# %%
a="This is a sentence."
b = "This is another sentence."

# %%
print("a:",a)
print("b:",b)
print("a,b:",a,b)

# %%
ABCD=a+" "+b

# %%
print("ABCD:",ABCD)

# %%
x=7.
y=8
print(x+y)

# %%
l=[6,7,8,9]

# %%
print(l)

# %%
print(l[0])

# %%
print(l[3])

# %%
print(len(l))

# %%
print(l[10])

# %% [markdown]
# ## Arithmetic and Boolean Operators

# %%
print(l[0],"+",l[2],"=",l[0]+l[2])

# %%
print(l[3],"-",l[1],"=",l[3]-l[1])

# %%
print(x,"*",y,"=",x*y)

# %%
print(y,"^2","=",y**2)

# %%
print(y,"^",l[0],"=",y**l[0])

# %%
print(l[3],"/",l[0],"=",l[3]/l[0])

# %%
print(l[3],"//",l[0],"=",l[3]//l[0])

# %%
print(l[3],"%",l[0],"=",l[3]%l[0])

# %%
l[3]+=l[0]
print(l[3])

# %%
print("l[3]=",l[3],"l[0]=",l[0])

l[3]-=l[0] #Same as l[3]=l[3]-l[0]

print("l[3]=",l[3],"l[0]=",l[0])

# %%
print("l[3]=",l[3],"l[0]=",l[0])

l[3]*=l[0] #Same as l[3]=l[3]*l[0]

# %%
print("l[3]=",l[3],"l[0]=",l[0])

# %%
print("l[3]=",l[3],"l[0]=",l[0])

l[3]/=l[0] #Same as l[3]=l[3]/l[0]

print("l[3]=",l[3],"l[0]=",l[0])

# %%
print(l[3]>l[0])

# %%
print(l[3]<l[0])

# %%
print(l[0]<l[0])

# %%
print(l[0]==l[0])

# %%
print(l[0]<=l[0])

# %%
print(l[3]>=l[0])
